# %%
import wfdb
import matplotlib.pyplot as plt

# Replace '100' with the record name you want to load
record = wfdb.rdrecord('40689238', pn_dir='mimic-iv-ecg') #loads record from mitdb database.
wfdb.plot_items(signal=record.p_signal, ann_samp=record.ann_samp, fs=record.fs, title='ECG signal')
plt.show()

#to read annotations.
annotation = wfdb.rdann('100', 'atr', pn_dir='mitdb')
# Out:
# ---------------------------------------------------------------------------
# NetFileNotFoundError                      Traceback (most recent call last)
# Cell In[11], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Replace '100' with the record name you want to load
# ----> 5 record = wfdb.rdrecord('40689238', pn_dir='https://physionet.org/content/mimic-iv-ecg/1.0/files/p1000/p10000032/s40689238/40689238.dat') #loads record from mitdb database.
#       6 wfdb.plot_items(signal=record.p_signal, ann_samp=record.ann_samp, fs=record.fs, title='ECG signal')
#       7 plt.show()
#
# File c:\Users\Alfredo\Desktop\Coding_Projects\ML\data-driven-biomedical-signal-analysis\.venv\Lib\site-packages\wfdb\io\record.py:2029, in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    2024     dir_list = pn_dir.split("/")
#    2025     pn_dir = posixpath.join(
# ...
